# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
goog_stock = pd.read_csv("Data/Train_data.csv")

# %%
goog_stock
# Out:
#             Date     Open    Close     High      Low   Volume
# 0       1/3/2012   326.19   332.70   334.07   326.18  3677850
# 1       1/4/2012   332.62   334.14   335.12   330.31  2864365
# 2       1/5/2012   330.87   329.50   331.98   328.11  3283277
# 3       1/6/2012   329.57   325.01   330.00   324.89  2694024
# 4       1/9/2012   323.25   311.23   323.50   310.61  5825720
# ...          ...      ...      ...      ...      ...      ...
# 2511  12/23/2021  2941.79  2942.85  2971.45  2939.02   690934
# 2512  12/27/2021  2949.27  2961.28  2968.53  2945.00   662966
# 2513  12/28/2021  2967.49  2928.96  2967.49  2918.71   931792
# 2514  12/29/2021  2928.59  2930.09  2943.68  2910.09   851236
# 2515  12/30/2021  2929.00  2920.05  2941.25  2915.17   648851
#
# [2516 rows x 6 columns]

# %%
goog_stock.info()
print("No. of entries = " , goog_stock.shape[0] , "\nNo. of columns = " , goog_stock.shape[1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2516 non-null   object
#  1   Open    2516 non-null   float64
#  2   Close   2516 non-null   float64
#  3   High    2516 non-null   float64
#  4   Low     2516 non-null   float64
#  5   Volume  2516 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 118.1+ KB
# No. of entries =  2516
# No. of columns =  6

# %%
goog_stock.describe()
# Out:
#               Open        Close         High          Low        Volume
# count  2516.000000  2516.000000  2516.000000  2516.000000  2.516000e+03
# mean    987.899583   988.419392   997.058442   979.028828  1.835125e+06
# std     627.094110   627.765280   633.185959   621.677266  9.780821e+05
# min     280.000000   279.520000   282.260000   278.260000  7.932000e+03
# 25%     537.745000   537.765000   541.150000   533.787500  1.259600e+06
# 50%     799.690000   798.190000   803.985000   793.795000  1.610515e+06
# 75%    1195.497500  1197.062500  1204.837500  1186.732500  2.113756e+06
# max    3020.000000  3014.180000  3037.000000  2997.750000  1.244235e+07

# %%
from datetime import datetime

# %%
# date_time = goog_stock['Date'].dt.strftime("%Y-%m-%d").head(500)
date_time = goog_stock['Date'].dt.strftime("%Y-%m-%d").head(500)
# date_time = pd.to_datetime(date_time)

# i = 0
# d = []
# for i in range(50):
#     d.append(date_time[i])

close_values = goog_stock['Close'].head(500)
close = []
i = 0
for i in range(500):
    close.append(close_values[i])

df = pd.DataFrame({'close' : close}, index=date_time)
ax = df.plot(x_compat=True, rot=90, figsize=(20, 15))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14208/2118454595.py in <module>
#       1 # date_time = goog_stock['Date'].dt.strftime("%Y-%m-%d").head(500)
# ----> 2 date_time = goog_stock['Date'].dt.strftime("%Y-%m-%d").head(500)
#       3 # date_time = pd.to_datetime(date_time)
#       4
#       5 # i = 0
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
close_values = goog_stock['Close'].head(500)
open
close = []
i = 0
for i in range(500):
    close.append(close_values[i])


cols = []
for col in goog_stock.columns:
    cols.append(col)

df = pd.DataFrame({'close' : close}, columns=cols, index=date_time)

# Defining index for the dataframe
idx = ['1', '2', '3', '4', '5']

# Entering values in the index and columns
# and converting them into a panda dataframe
df = pd.DataFrame([[10, 20, 30, 40], [50, 30, 8, 15],
				[25, 14, 41, 8], [7, 14, 21, 28]],
				columns = cols[1:4], index = idx)

# generating pairwise correlation
corr = df.corr()

# Displaying dataframe as an heatmap
# with diverging colourmap as coolwarm
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_11abc_row0_col0, #T_11abc_row1_col1, #T_11abc_row2_col2, #T_11abc_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_11abc_row0_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_11abc_row0_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_11abc_row0_col3, #T_11abc_row1_col2, #T_11abc_row2_col1, #T_11abc_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_11abc_row1_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_11abc_row1_col3, #T_11abc_row2_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_11abc_row2_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_11abc_row3_col1, #T_11abc_row3_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# </style>
# <table id="T_11abc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
# ...

# %%
# Out:
# Date
# Open
# Close
# High
# Low
# Volume

# %%
date_time = ["2011-09-01", "2011-08-01", "2011-07-01", "2011-06-01", "2011-05-01"]

# convert the list of strings to a datetime and .date will remove the time component
date_time = pd.to_datetime(date_time).date
temp = [2, 4, 6, 4, 6]
print(temp)
print(date_time)
DF = pd.DataFrame({'temp': temp}, index=date_time)

ax = DF.plot(x_compat=True, rot=90, figsize=(6, 5))
# Out:
# [2, 4, 6, 4, 6]
# [datetime.date(2011, 9, 1) datetime.date(2011, 8, 1)
#  datetime.date(2011, 7, 1) datetime.date(2011, 6, 1)
#  datetime.date(2011, 5, 1)]

# %%
# defining index for the dataframe
idx = ['Open', 'Close', 'High', 'Low']

cols = []
# defining columns for the dataframe
for i in range(0, 2516):
    cols.append(i)

op = list(goog_stock['Open'])
cl = list(goog_stock['Close'])
high = list(goog_stock['High'])
low = list(goog_stock['Low'])

# entering values in the index and columns
# and converting them into a panda dataframe
df = pd.DataFrame([op, cl, high, low], columns = cols, index = idx)
corr = df.corr()
# displaying dataframe as an heatmap
# with diverging colourmap as virdis
corr.style.background_gradient(cmap ='viridis').set_properties(**{'font-size': '20px'})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1036/1854166134.py in <module>
#      18 # displaying dataframe as an heatmap
#      19 # with diverging colourmap as virdis
# ---> 20 corr.style.background_gradient(cmap ='viridis').set_properties(**{'font-size': '20px'})
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# ...

# %%
from LocalitySensitiveHashing import *
datafile = "Data/Train_data_forHASH.csv"
lsh = LocalitySensitiveHashing(
                   datafile = datafile,
                   dim = 10,
                   r = 50,
                   b = 100,
                   expected_num_of_clusters = 10,
)
lsh.get_data_from_csv()
lsh.initialize_hash_store()
lsh.hash_all_data()
similarity_groups = lsh.lsh_basic_for_neighborhood_clusters()
coalesced_similarity_groups = lsh.merge_similarity_groups_with_coalescence( similarity_groups )
merged_similarity_groups = lsh.merge_similarity_groups_with_l2norm_sample_based( coalesced_similarity_groups )
lsh.write_clusters_to_file( merged_similarity_groups, "clusters.txt" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14208/2211265519.py in <module>
#      10 lsh.get_data_from_csv()
#      11 lsh.initialize_hash_store()
# ---> 12 lsh.hash_all_data()
#      13 similarity_groups = lsh.lsh_basic_for_neighborhood_clusters()
#      14 coalesced_similarity_groups = lsh.merge_similarity_groups_with_coalescence( similarity_groups )
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\LocalitySensitiveHashing\LocalitySensitiveHashing.py in hash_all_data(self)
#     872                 hplane_vals = hplane.translate(bytes.maketrans(b"][", b"  ")) \
#     873                        if sys.version_info[0] == 3 else hplane.translate(string.maketrans("][","  "))
# --> 874                 bin_val = numpy.dot(list(map(convert, hplane_vals.split())), self._data_dict[sample])
# ...
